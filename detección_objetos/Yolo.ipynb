# %% [markdown]
# ### Montar el Sistema de archivos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Cambiar directorio de trabajo

# %%
import os 
os.chdir("drive/My Drive/Tutoriales Deep Learning/detección_objetos")# CAMBIAR POR LA RUTA DE TU NOTEBOOK

# %%
# !ls
# Out:
# images	Yolo.ipynb  yolov3.weights

# %% [markdown]
# ### Instala Darknetpy

# %%
# !pip install  darknetpy
# Out:
# ...
#      |████████████████████████████████| 419kB 3.4MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   ERROR: Failed building wheel for darknetpy
#   Running setup.py clean for darknetpy
# Failed to build darknetpy
# ERROR: Could not build wheels for darknetpy which use PEP 517 and cannot be installed directly

# %%
import darknet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-f60dcba81d77> in <module>()
# ----> 1 import darknet
#
# ModuleNotFoundError: No module named 'darknet'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Otra Manera

# %%
# !git clone https://github.com/pjreddie/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5901, done.
# remote: Total 5901 (delta 0), reused 0 (delta 0), pack-reused 5901
# Receiving objects: 100% (5901/5901), 6.17 MiB | 9.91 MiB/s, done.
# Resolving deltas: 100% (3916/3916), done.
# Checking out files: 100% (979/979), done.

# %%
os.chdir("darknet")

# %%
# !ls
# Out:
# cfg	  include	LICENSE.gen   LICENSE.mit  python     src
# data	  LICENSE	LICENSE.gpl   LICENSE.v1   README.md
# examples  LICENSE.fuck	LICENSE.meta  Makefile	   scripts

# %%
# !make
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv` -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -c ./src/gemm.c -o obj/gemm.o
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv` -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv` -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -c ./src/cuda.c -o obj/cuda.o
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv` -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -c ./src/deconvolutional_layer.c -o obj/deconvolutional_layer.o
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv` -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %%
# !nvidia-smi
# Out:
# Tue Jan 21 19:39:16 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.44       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Tutoriales Deep Learning/detección_objetos/darknet'

# %%
os.chdir('..')

# %%
# !ls
# Out:
# darknet  images  Yolo.ipynb  yolov3.weights

# %% [markdown]
# # Descarga los pesos entrenados

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights

# %%
# !ls
# Out:
# darknet  images  Yolo.ipynb  yolov3.weights

# %%
os.chdir('darknet')

# %%
# !ls
# Out:
# backup	 examples	LICENSE       LICENSE.meta  obj        scripts
# cfg	 include	LICENSE.fuck  LICENSE.mit   python     src
# darknet  libdarknet.a	LICENSE.gen   LICENSE.v1    README.md
# data	 libdarknet.so	LICENSE.gpl   Makefile	    results

# %%
# !./darknet  detect cfg/yolov3.cfg ../yolov3.weights ../images/cars.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#    10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
# ...

# %%
# Out:
# images	Yolo.ipynb  yolov3.weights

# %% [markdown]
# ###Links
# * https://hackernoon.com/object-detection-in-google-colab-with-custom-dataset-5a7bb2b0e97e
# *https://medium.com/@nickbortolotti/tensorflow-object-detection-api-in-5-clicks-from-colaboratory-843b19a1edf1
# * https://medium.com/@moshe.livne/training-tensorflow-for-free-pet-object-detection-api-sample-trained-on-google-collab-c2e65f4a9949
#
# *https://towardsdatascience.com/object-detection-using-yolo-in-google-colab-7d5fe7db3485
#
#
# * https://chamaradodandeniya.wordpress.com/2019/04/16/how-to-configure-google-colab-for-object-detection-using-tensorflow/
